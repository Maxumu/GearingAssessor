# %%
from main import *
from config import GearConfig
from config import VarStore
import hvplot.pandas
import panel as pn
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3491b886-5f47-4c59-ad56-38846a0c2320'>
#   <div id="caab86b8-9d8c-4040-ab1e-fe5d72b9f326" data-root-id="3491b886-5f47-4c59-ad56-38846a0c2320" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
config = GearConfig(use_real=False,use_generated=True,max_rear=6,largest_rear=22)
print(type(score(config,"quarters")))
# print(type(all_scores_df))

# @pn.depends(dataset_selector)
def plot_data(data):
    # x_value = all_scores_df["Worst Efficiency"]
    # y_value = all_scores_df["Range"]
    return(all_scores_df.hvplot.scatter(x="Worst Efficiency", y="Range"))

plot_data(all_scores_df)
# Out:
# sprocket_generator done, generated: 924
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 config = GearConfig(use_real=False,use_generated=True,max_rear=6,largest_rear=22)
# ----> 2 print(type(score(config,"quarters")))
#       3 # print(type(all_scores_df))
#       4
#       5 # @pn.depends(dataset_selector)
#       6 def plot_data(data):
#       7     # x_value = all_scores_df["Worst Efficiency"]
#       8     # y_value = all_scores_df["Range"]
#
# File ~/PycharmProjects/GitStuff/main.py:398, in score(config, pattern)
#     396 # Finds proportional difference from optimal cadence, applies it to efficiency func for worst efficiency shift
#     397 best_cad = peak_cadence
# ...

# %%
interactive_plot
# Out:
# Column
#     [0] Select(options=['11-12-13-14-15-16_50-34'...], value='11-12-13-14-15-16_50-34')
#     [1] ParamFunction(function, _pane=HoloViews, defer_load=False)
