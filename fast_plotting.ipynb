# %%
import main

# %%
# %run main.py
# Out:
# Running
# sprocket_generator done, generated: 1
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# score done
# results_plotter done
# sprocket_generator done, generated: 7
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# score done
# results_plotter done
# sprocket_generator done, generated: 28
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# score done
# results_plotter done
# sprocket_generator done, generated: 84
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# score done
# results_plotter done
# sprocket_generator done, generated: 210
# gearset_generator done
# calculate_ratios done
# drivetrain_splitter done
# shifting_pattern done
# calculate_jumps done
# score done
# ...
