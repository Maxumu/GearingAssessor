# %%
import main

# %%
# %run main.py
# Out:
# Running
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/PycharmProjects/GitStuff/main.py:498
#     496 generated = True
#     497 best_cadence()
# --> 498 results_plotter_matplotlib(score("quarters"))
#     499 end = time.time()
#     500 duration = end - start
#
# File ~/PycharmProjects/GitStuff/main.py:389, in score(pattern)
#     379 """
#     380 Input:
#     381     Groupset dataframe with ratio jumps
#    (...)
#     386     FUTURE: efficiency from bio data
#     387     """
#     388 scores_dict = {}
# --> 389 groupsets = calculate_jumps(pattern)
#     391 for key, df in groupsets.items():
#     392     score = []
#
# File ~/PycharmProjects/GitStuff/main.py:262, in calculate_jumps(pattern)
#     255 def calculate_jumps(pattern):
#     256     """
#     257     Input:
#     258         Pandas dataframe formatted database for each single combination
# ...

# %%
import config

# %%
print(config(GearConfig))
# Out:
#   Cell In[27], line 1
#     print(config: GearConfig)
#                 ^
# SyntaxError: invalid syntax
